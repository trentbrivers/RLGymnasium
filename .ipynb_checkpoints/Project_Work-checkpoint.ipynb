# %% [markdown]
# # **Trent Rivers Final Project**
#
# ## **Greetings!**
#
# In this project, I am going to be attempting to implement reinforcement learning on OpenAI's Bipedal Walker environment. This environment was selected because I am particularly interested in Machine Learning enabled locomotion. This environment allows me to experiment with that without dealing with the dependencies and installations required for more complex MuJoCo environments provided in Gymnasium. This environment also provides the agent with a greater range of options since we are not using discrete action values. I'm interested to see the results.

# %%
#Handling proper libraries.
# !pip install gymnasium
# !pip install swig
# !pip install gymnasium[box2d]
# !pip install matplotlib
# Out:
# ...
#   Using cached gymnasium-1.1.1-py3-none-any.whl (965 kB)
# ...
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# ...
#   Using cached swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
# ...
#   Using cached box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl
# ...
#   Using cached pygame-2.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
# ...

# %%
import gymnasium as gym
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython import display
import numpy as np
from collections import defaultdict

# %%
#Code taken from the cartpole-updated notebook

def show_state(env, step=0, info=""):
    plt.figure(3)
    plt.clf()
    plt.imshow(env.render())
    plt.title("%s | Step: %d %s" % (env.spec.id,step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())
    
def replay(policy):
    env = gym.make("BipedalWalker-v3", render_mode = "rgb_array")
    obs = env.reset()
    step = 0
    for a in policy:
        env.step(a)
        show_state(env, step)
        step+=1

# %% [markdown]
# ## **The Environment**
#
# The Bipedal Walker environment uses a 4-jointed walker to traverse a 2D environment - it's like a box with two simple legs. The actions available are motor speed values in the range [-1, 1] for each of the 4 joints.
#
# The bipedal walker agent accumulates rewards by moving forward (to the right), up to 300+ at the far end. If it falls, it immediately receives -100 points and the episode is terminated. According to the documentation, this problem is "solved" when the agent can clear 300 points in 1600 time steps on normal mode (slightly bumpy terrain) or 2000 time steps in hardcore mode (with obstacles the agents will need to overcome).
#
# Let's test the performance of a random agent below to establish a baseline.

# %%
import datetime
from tqdm import tqdm

env = gym.make("BipedalWalker-v3", render_mode = "rgb_array")
best_policy = []
best_reward = float('-inf')
rewards = []

def one_episode():
    total_reward = 0.0
    total_steps = 0
    obs = env.reset()
    policy = []

    while total_steps < 1600:
        action = env.action_space.sample() #.sample method gives a random action sample
        obs, reward, done, _, _ = env.step(action)
        policy.append(action)
        total_reward += reward
        total_steps += 1
        if done:
            break
            
    return total_reward, policy

for i in range(1000):
    r, p = one_episode()
    rewards.append(r)
    if r > best_reward:
        best_policy = p

plt.hist(rewards, edgecolor='black')
plt.xlim(-150, 300)
plt.xlabel("Rewards")
plt.ylabel("Count")
plt.title("Random Agent Performance")
plt.show()
#now = datetime.datetime.now()
#current_time = now.strftime("%H-%M-%S")
#plt.savefig("figure"+str(current_time) + ".png")

# %%
replay(best_policy)

# %%
env.action_space.sample()
# Out:
# array([ 0.81186736,  0.3281564 ,  0.12366715, -0.25033134], dtype=float32)

# %% [markdown]
# What you should see above is that the random agent entirely fails to reach a score exceeding even -50. From my own testing, the policy that works best thus far (which you should observe in the replay above) is the agent straddling its legs and inching along ever so slowly. From my own testing, the policy that works best thus far (which you should observe in the replay above) is the agent straddling its legs and inching along ever so slowly. It is clear from the above that a random policy is not optimal in this environment, and that improvements need to be made to the policy in order to "solve" our desired task.
#
# ## **I have encountered a problem**
# I have a hit a brick wall. Let me explain. This particular problem encodes action as a 4-vector of floating point values in the range [-1, 1]. Since actions are a vector of floating points and not discrete values, the possible combinations of state-action pairs for something like q-learning are almost innumerable. This makes Q-learning unfeasible because we can not tabulate all of the possible Q-values. This is the first challenge.
#
# The second is that, given the structure of Gymnasium and the Env class, the information we have access to about the environment is extremely limited. Since information is so limited, it is not possible, at least in my present view, to implement approximate Q-Learning with a feature based representation because there is no way to define the necessary features.
#
# In light of this challenge, which I'm currently unable to resolve, I will be changing course to focus on a different Gymnasium environment: Taxi.
